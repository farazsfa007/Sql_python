# %%
import pandas as pd

# %%
df = pd.read_excel('dataset.xlsx')

# %%
df
# Out:
#      Employee ID  Gender Job Level after FY20 promotions New hire FY20?  \
# 0              1    Male              6 - Junior Officer              N
# 1              2  Female                     4 - Manager              N
# 2              3    Male                    2 - Director              N
# 3              4    Male                     4 - Manager              N
# 4              5  Female              6 - Junior Officer              N
# ..           ...     ...                             ...            ...
# 495          496    Male              6 - Junior Officer              N
# 496          497  Female              5 - Senior Officer              N
# 497          498    Male              6 - Junior Officer              N
# 498          499    Male              3 - Senior Manager              N
# 499          500    Male                     4 - Manager              N
#
#      FY20 Performance Rating Promotion in FY21?  \
# 0                        2.0                 No
# ...

# %%
df.head()
# Out:
#    Employee ID  Gender Job Level after FY20 promotions New hire FY20?  \
# 0            1    Male              6 - Junior Officer              N
# 1            2  Female                     4 - Manager              N
# 2            3    Male                    2 - Director              N
# 3            4    Male                     4 - Manager              N
# 4            5  Female              6 - Junior Officer              N
#
#    FY20 Performance Rating Promotion in FY21?  \
# 0                      2.0                 No
# 1                      3.0                 No
# 2                      2.0                 No
# 3                      3.0                 No
# 4                      2.0                 No
#
#   In base group for Promotion FY21  Target hire balance FY20 leaver?  \
# 0                               No                  0.5          Yes
# 1                              Yes                  0.5           No
# ...

# %%
df
# Out:
#      Employee ID  Gender Job Level after FY20 promotions New hire FY20?  \
# 0              1    Male              6 - Junior Officer              N
# 1              2  Female                     4 - Manager              N
# 2              3    Male                    2 - Director              N
# 3              4    Male                     4 - Manager              N
# 4              5  Female              6 - Junior Officer              N
# ..           ...     ...                             ...            ...
# 495          496    Male              6 - Junior Officer              N
# 496          497  Female              5 - Senior Officer              N
# 497          498    Male              6 - Junior Officer              N
# 498          499    Male              3 - Senior Manager              N
# 499          500    Male                     4 - Manager              N
#
#      FY20 Performance Rating Promotion in FY21?  \
# 0                        2.0                 No
# ...

# %%
df.head()
# Out:
#    Employee ID  Gender Job Level after FY20 promotions New hire FY20?  \
# 0            1    Male              6 - Junior Officer              N
# 1            2  Female                     4 - Manager              N
# 2            3    Male                    2 - Director              N
# 3            4    Male                     4 - Manager              N
# 4            5  Female              6 - Junior Officer              N
#
#    FY20 Performance Rating Promotion in FY21?  \
# 0                      2.0                 No
# 1                      3.0                 No
# 2                      2.0                 No
# 3                      3.0                 No
# 4                      2.0                 No
#
#   In base group for Promotion FY21  Target hire balance FY20 leaver?  \
# 0                               No                  0.5          Yes
# 1                              Yes                  0.5           No
# ...

# %%
df
# Out:
# Employee ID                                            1
# Gender                                              Male
# Job Level after FY20 promotions       6 - Junior Officer
# New hire FY20?                                         N
# FY20 Performance Rating                              2.0
# Promotion in FY21?                                    No
# In base group for Promotion FY21                      No
# Target hire balance                                  0.5
# FY20 leaver?                                         Yes
# In base group for turnover FY20                        Y
# Department @01.07.2020                        Operations
# Leaver FY                                           FY20
# Job Level after FY21 promotions                      NaN
# Last Department in FY20                       Operations
# FTE group                                      Full Time
# Time type                                      Full Time
# ...

# %%
df.tail()
# Out:
#      Employee ID  Gender Job Level after FY20 promotions New hire FY20?  \
# 495          496    Male              6 - Junior Officer              N
# 496          497  Female              5 - Senior Officer              N
# 497          498    Male              6 - Junior Officer              N
# 498          499    Male              3 - Senior Manager              N
# 499          500    Male                     4 - Manager              N
#
#      FY20 Performance Rating Promotion in FY21?  \
# 495                      4.0                 No
# 496                      2.0                 No
# 497                      2.0                 No
# 498                      2.0                 No
# 499                      2.0                Yes
#
#     In base group for Promotion FY21  Target hire balance FY20 leaver?  \
# 495                              Yes                  0.5           No
# 496                              Yes                  0.5           No
# ...

# %%
df[]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python312\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df[1]
#
# ...
